# %% [markdown]
# # Currency exchange rate trends analyzer

# %% [markdown]
# ### Trend analysis for EURPLN exchange rates using data from 2013.09.09 to 2016.09.05 time period

# %%
# customarilily import most important libraries

import pandas as pd                       # pandas is a dataframe library
import matplotlib.pyplot as plt           # matplotlib.pyplot plots data
import numpy as np                        # numpy provides N-dim object support

import matplotlib.dates as mdates         


# do ploting inline instead of in a separate window
# %matplotlib inline

# %%
df = pd.read_csv('./data-archive/EUR_2013.09.09_2016.09.05.csv', sep=';')     # load data

# %%
# get brief statistics over data we just read
df_columns, df_rows = df.shape

print("File contains {} rows and {} columns of data.".format(df_columns, df_rows))
# Out:
# File contains 755 rows and 4 columns of data.

# %% [markdown]
# #### Show first 3 rows from file

# %%
df.head(3)
# Out:
#          Data    Kurs  Zmiana    Nazwa Tabeli
# 0  2016-09-05  4.3480   -0.72  171/A/NBP/2016
# 1  2016-09-02  4.3796    0.43  170/A/NBP/2016
# 2  2016-09-01  4.3607    0.12  169/A/NBP/2016

# %% [markdown]
# #### Show last 3 rows from file

# %%
df.tail(3)
# Out:
#            Data    Kurs  Zmiana    Nazwa Tabeli
# 752  2013-09-11  4.2408   -0.54  176/A/NBP/2013
# 753  2013-09-10  4.2637   -0.15  175/A/NBP/2013
# 754  2013-09-09  4.2700   -0.64  174/A/NBP/2013

# %% [markdown]
# As we can see, data are not ordered chronologically. We must reverse the order of rows so that first row is the oldest, last row is the newest.

# %%
df = df.sort_index(axis=0, ascending=True)
df = df.iloc[::-1]
df.head(3)
# Out:
#            Data    Kurs  Zmiana    Nazwa Tabeli
# 754  2013-09-09  4.2700   -0.64  174/A/NBP/2013
# 753  2013-09-10  4.2637   -0.15  175/A/NBP/2013
# 752  2013-09-11  4.2408   -0.54  176/A/NBP/2013

# %%
df.tail(3)
# Out:
#          Data    Kurs  Zmiana    Nazwa Tabeli
# 2  2016-09-01  4.3607    0.12  169/A/NBP/2016
# 1  2016-09-02  4.3796    0.43  170/A/NBP/2016
# 0  2016-09-05  4.3480   -0.72  171/A/NBP/2016

# %% [markdown]
# Data frame (rows) is reversed now, which we can prove by observing values on the diagram

# %%
plt.plot(df['Kurs'].values)

# %% [markdown]
# ### SMA - simple moving average

# %%
# an example on how to calculate SMA for a collection of data
v = {'score': [1, 2, 2, 3, 3, 4]}
data_frame = pd.DataFrame(v)
pd.rolling_mean(data_frame, 2)
# Out:
#    score
# 0    NaN
# 1    1.5
# 2    2.0
# 3    2.5
# 4    3.0
# 5    3.5

# %% [markdown]
# #### Calculate various SMA

# %% [markdown]
# In order to perform better analysis, we will use recent data

# %%
# get last 100 exchange rates
last_days_to_analyze = 300
last_days_to_observe = 200

recent_exchange_rates = df['Kurs'].values[-last_days_to_analyze:]
recent_dates = df['Data'].values[-last_days_to_analyze:]

# %%
# create new DataFrame containing exchange rates ordered chronologically (oldest first, newest last)
df_exchange_rates = pd.DataFrame(recent_exchange_rates)

# define SMA windows (for short-term trading)
sma_windows = [3, 5, 7, 10, 20, 50]

# calculate SMA-3, SMA-5 and so on..
df_sma = {}
for window in sma_windows:
    df_sma[window] = pd.rolling_mean(df_exchange_rates, window)

# %%
# get data for last days we are interested in
recent_exchange_rates = recent_exchange_rates[-last_days_to_observe:]
recent_dates = recent_dates[-last_days_to_observe:]

# %% [markdown]
# #### Plot exchange rates along with different SMA

# %%
plt.figure(figsize=(20,7))

plt.plot(recent_exchange_rates)
# sma-10
plt.plot(df_sma[10][-last_days_to_observe:].values)
# sma-20
plt.plot(df_sma[20][-last_days_to_observe:].values)
# sma-50
plt.plot(df_sma[50][-last_days_to_observe:].values)

plt.legend(['exchange rates', 'SMA-10', 'SMA-20', 'SMA-50'], loc='upper left')

# %% [markdown]
# ### Example on how to find points where the curves intersect

# %%
x = np.arange(0, 1000)
f = np.arange(0, 1000)
g = np.sin(np.arange(0, 10, 0.01)) * 1000

plt.plot(x, f, '-')
plt.plot(x, g, '-')

idx = np.argwhere(np.isclose(f, g, atol=10)).reshape(-1)
plt.plot(x[idx], f[idx], 'ro')
plt.show()

# %% [markdown]
# #### Let's analyze which SMA is the best in terms of mirroring trend

# %%
plt.figure(figsize=(20,10))

# plot unchanged history of exchange rates
plt.plot(recent_exchange_rates)

legend = []
legend.append('exchange rates')
for window in sma_windows:
    plt.plot(df_sma[window][-last_days_to_observe:].values)
    legend.append('SMA-{}'.format(window))
    
# plot dynamically created legend
plt.legend(legend, loc='upper left')

# %% [markdown]
# Concusion: The SMA-3, SMA-5, SMA-7, and SMA-10 are the best dataset in terms of mirroring exchange rates

# %% [markdown]
# #### Calculate intersection points between various SMA data ranges

# %%
def plot_pair(pair):
    window1 = pair[0]
    window2 = pair[1]
    # get SMA values for interesting windows
    sma1 = df_sma[window1][-last_days_to_observe:].values
    sma2 = df_sma[window2][-last_days_to_observe:].values
    # calculate crossing points between both value ranges
    intersection_points = np.argwhere(np.isclose(sma1, sma2, atol=0.01)).reshape(-1)
    # plot
    plt.plot(sma1)
    plt.plot(sma2)
    plt.plot(intersection_points, sma1[intersection_points], 'go')
    plt.plot(intersection_points, sma2[intersection_points], 'ro')
    plt.xticks(np.arange(0, last_days_to_observe, 10))
    # return
    return list(intersection_points)[::2]


# set up plotting parameters
plt.figure(figsize=(20,10))
plt.grid(True)

#plt.plot(recent_exchange_rates)    
comparison_pair = (3, 10)
intersection_points = plot_pair(comparison_pair)
#plt.legend(['exchange rates', "SMA-{}".format(comparison_pair[0]), "SMA-{}".format(comparison_pair[1])], loc='upper left')

# %% [markdown]
# #### What's wrong with intersection between 40-50??

# %%
test_sma_1 = df_sma[3][-160:-150].values
test_sma_2 = df_sma[10][-160:-150].values

intpoint = np.argwhere(np.isclose(test_sma_1, test_sma_2, atol=0.01)).reshape(-1)

plt.plot(test_sma_1)
plt.plot(test_sma_2)
plt.plot(intpoint, test_sma_1[intpoint], 'go')
plt.plot(intpoint, test_sma_2[intpoint], 'ro')

# %%
print("Intersection points between SMA-{} and SMA-{}".format(comparison_pair[0], comparison_pair[1]))
print(intersection_points)
print()
print("Exchange rates on such days:")
for i in intersection_points:
    print("{} ==> date: {}, exchange rate: {}".format(i, recent_dates[i], recent_exchange_rates[i]))
print()
# Out:
# Intersection points between SMA-3 and SMA-10
# [0, 1, 2, 3, 6, 7, 8, 9, 19, 28, 29, 46, 47, 54, 55, 57, 58, 59, 66, 67, 68, 74, 75, 76, 77, 87, 88, 89, 90, 91, 92, 93, 94, 95, 96, 103, 104, 105, 106, 116, 118, 120, 121, 125, 126, 130, 131, 135, 140, 146, 147, 149, 150, 152, 153, 154, 155, 156, 158, 159, 160, 161, 162, 163, 172, 173, 174, 175, 176, 186, 187, 188, 189]
#
# Exchange rates on such days:
# 0 ==> date: 2015-11-20, exchange rate: 4.2441
# 1 ==> date: 2015-11-23, exchange rate: 4.2395
# 2 ==> date: 2015-11-24, exchange rate: 4.2609
# 3 ==> date: 2015-11-25, exchange rate: 4.268
# 6 ==> date: 2015-11-30, exchange rate: 4.2639
# 7 ==> date: 2015-12-01, exchange rate: 4.2651
# 8 ==> date: 2015-12-02, exchange rate: 4.2815
# 9 ==> date: 2015-12-03, exchange rate: 4.2665
# 19 ==> date: 2015-12-17, exchange rate: 4.3048
# 28 ==> date: 2015-12-31, exchange rate: 4.2615
# 29 ==> date: 2016-01-04, exchange rate: 4.2935
# 46 ==> date: 2016-01-28, exchange rate: 4.4588
# 47 ==> date: 2016-01-29, exchange rate: 4.4405
# 54 ==> date: 2016-02-09, exchange rate: 4.449
# 55 ==> date: 2016-02-10, exchange rate: 4.4366
# 57 ==> date: 2016-02-12, exchange rate: 4.4136
# 58 ==> date: 2016-02-15, exchange rate: 4.396
# 59 ==> date: 2016-02-16, exchange rate: 4.4042
# 66 ==> date: 2016-02-25, exchange rate: 4.3739
# 67 ==> date: 2016-02-26, exchange rate: 4.357
# 68 ==> date: 2016-02-29, exchange rate: 4.3589
# 74 ==> date: 2016-03-08, exchange rate: 4.3325
# 75 ==> date: 2016-03-09, exchange rate: 4.3215
# 76 ==> date: 2016-03-10, exchange rate: 4.3131
# 77 ==> date: 2016-03-11, exchange rate: 4.3226
# 87 ==> date: 2016-03-25, exchange rate: 4.263
# 88 ==> date: 2016-03-29, exchange rate: 4.2535
# 89 ==> date: 2016-03-30, exchange rate: 4.2445
# 90 ==> date: 2016-03-31, exchange rate: 4.2684
# 91 ==> date: 2016-04-01, exchange rate: 4.2387
# 92 ==> date: 2016-04-04, exchange rate: 4.2355
# 93 ==> date: 2016-04-05, exchange rate: 4.2452
# 94 ==> date: 2016-04-06, exchange rate: 4.2577
# 95 ==> date: 2016-04-07, exchange rate: 4.2601
# 96 ==> date: 2016-04-08, exchange rate: 4.293
# 103 ==> date: 2016-04-19, exchange rate: 4.2977
# 104 ==> date: 2016-04-20, exchange rate: 4.3004
# 105 ==> date: 2016-04-21, exchange rate: 4.2885
# 106 ==> date: 2016-04-22, exchange rate: 4.3283
# 116 ==> date: 2016-05-09, exchange rate: 4.4123
# 118 ==> date: 2016-05-11, exchange rate: 4.4241
# 120 ==> date: 2016-05-13, exchange rate: 4.4016
# 121 ==> date: 2016-05-16, exchange rate: 4.3727
# 125 ==> date: 2016-05-20, exchange rate: 4.4163
# 126 ==> date: 2016-05-23, exchange rate: 4.4293
# 130 ==> date: 2016-05-30, exchange rate: 4.3945
# 131 ==> date: 2016-05-31, exchange rate: 4.382
# 135 ==> date: 2016-06-06, exchange rate: 4.3835
# 140 ==> date: 2016-06-13, exchange rate: 4.39
# 146 ==> date: 2016-06-21, exchange rate: 4.3935
# 147 ==> date: 2016-06-22, exchange rate: 4.39
# 149 ==> date: 2016-06-24, exchange rate: 4.4526
# 150 ==> date: 2016-06-27, exchange rate: 4.4485
# 152 ==> date: 2016-06-29, exchange rate: 4.414
# 153 ==> date: 2016-06-30, exchange rate: 4.4255
# 154 ==> date: 2016-07-01, exchange rate: 4.3921
# 155 ==> date: 2016-07-04, exchange rate: 4.4304
# 156 ==> date: 2016-07-05, exchange rate: 4.4501
# 158 ==> date: 2016-07-07, exchange rate: 4.438
# 159 ==> date: 2016-07-08, exchange rate: 4.4295
# 160 ==> date: 2016-07-11, exchange rate: 4.417
# 161 ==> date: 2016-07-12, exchange rate: 4.4224
# 162 ==> date: 2016-07-13, exchange rate: 4.4016
# 163 ==> date: 2016-07-14, exchange rate: 4.407
# 172 ==> date: 2016-07-27, exchange rate: 4.3695
# 173 ==> date: 2016-07-28, exchange rate: 4.3736
# 174 ==> date: 2016-07-29, exchange rate: 4.3684
# 175 ==> date: 2016-08-01, exchange rate: 4.3576
# 176 ==> date: 2016-08-02, exchange rate: 4.3484
# 186 ==> date: 2016-08-17, exchange rate: 4.2863
# 187 ==> date: 2016-08-18, exchange rate: 4.2837
# 188 ==> date: 2016-08-19, exchange rate: 4.2884
# 189 ==> date: 2016-08-22, exchange rate: 4.303

# %%
# TODO: would be great to eliminate consecutive dates
